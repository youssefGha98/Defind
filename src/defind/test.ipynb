# %%
from defind.fetcher import fetch_decode_streaming_to_shards


MAX_STEPS = 19_999
MID_STEPS = 10_000
LOW_STEPS = 5_000
summary = await fetch_decode_streaming_to_shards(
    rpc_url="https://optimism-mainnet.chainnodes.org/6457c046-a111-448d-8997-3e164fe1149b",
    address="0x478946bcd4a5a22b316470f5486fafb928c0ba25",
    topic0s=["0x7a53080ba414158be7ec69b987b5fb7d07dee101fe85488f0853ae16239d0bde", "0x0c396cd989a39f4459b5fa1aed6a9a8dcdbc45908acfd67e028cd568da98982c",
    "0x70935338e69775456a85ddef226c395fb668b63fa0115f5f20610b388e6ca9c0", "0x205860e66845f2bbc0966bfab80db9bf93fca93862ea2b9fcf6945748352b4a3"],
    start_block=121535577,
    end_block="latest",
    step=MAX_STEPS,
    concurrency=23,
    out_root="data",
)

print(summary)
# Out:
# 💾 wrote shard 00001 → test/0x478946bcd4a5a22b316470f5486fafb928c0ba25__topics-7ff435afcc/shards/shard_00001.parquet  (rows=250000)
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[1], line 7
#       5 MID_STEPS = 10_000
#       6 LOW_STEPS = 5_000
# ----> 7 summary = await fetch_decode_streaming_to_shards(
#       8     rpc_url="https://optimism-mainnet.chainnodes.org/6457c046-a111-448d-8997-3e164fe1149b",
#       9     address="0x478946bcd4a5a22b316470f5486fafb928c0ba25",
#      10     topic0s=["0x7a53080ba414158be7ec69b987b5fb7d07dee101fe85488f0853ae16239d0bde", "0x0c396cd989a39f4459b5fa1aed6a9a8dcdbc45908acfd67e028cd568da98982c",
#      11     "0x70935338e69775456a85ddef226c395fb668b63fa0115f5f20610b388e6ca9c0", "0x205860e66845f2bbc0966bfab80db9bf93fca93862ea2b9fcf6945748352b4a3"],
#      12     start_block=121535577,
#      13     end_block="latest",
#      14     step=MAX_STEPS,
#      15     concurrency=23,
#      16     out_root="test",
#      17 )
#      19 print(summary)
#
# File ~/define/src/defind/fetcher.py:668, in fetch_decode_streaming_to_shards(rpc_url, address, topic0s, start_block, end_block, step, concurrency, out_root, rows_per_shard, batch_decode_rows, timeout_s, min_split_span, write_final_partial)
#     665                 stats["processed_failed"] += 1
#     666                 await manifest.append(ChunkRecord(a,b,"failed",1,str(e),0,0,0,time.time(),0))
# --> 668 await asyncio.gather(*(asyncio.create_task(process_interval(fb, tb)) for fb, tb in seeds))
#     670 async with agg_lock:
#     671     last = agg.close()  # writes the final partial shard iff write_final_partial=True
#
# File ~/define/src/defind/fetcher.py:612, in fetch_decode_streaming_to_shards.<locals>.process_interval(fb, tb)
#     610 try:
#     611     async with sem:
# --> 612         logs = await rpc.get_logs(address=address, topic0s=topic0s, from_block=a, to_block=b)
#     613     stats["executed_subranges"] += 1
#     614     stats["total_logs"] += len(logs)
#
# File ~/define/src/defind/fetcher.py:235, in RPC.get_logs(self, address, topic0s, from_block, to_block)
#     232 async def get_logs(self, *, address: str, topic0s: Sequence[str], from_block: int, to_block: int) -> list[EventLog]:
#     233     params = [{"address":address.lower(),"fromBlock":_to_hex_block(from_block),
#     234                "toBlock":_to_hex_block(to_block),"topics":_topics_param(topic0s)}]
# --> 235     r = await self.client.post(self.url, json={"jsonrpc":"2.0","id":1,"method":"eth_getLogs","params":params})
#     236     r.raise_for_status()
#     237     data = r.json()
#
# File ~/define/.venv/lib/python3.12/site-packages/httpx/_client.py:1859, in AsyncClient.post(self, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1838 async def post(
#    1839     self,
#    1840     url: URL | str,
#    (...)   1852     extensions: RequestExtensions | None = None,
#    1853 ) -> Response:
#    1854     """
#    1855     Send a `POST` request.
#    1856
#    1857     **Parameters**: See `httpx.request`.
#    1858     """
# -> 1859     return await self.request(
#    1860         "POST",
#    1861         url,
#    1862         content=content,
#    1863         data=data,
#    1864         files=files,
#    1865         json=json,
#    1866         params=params,
#    1867         headers=headers,
#    1868         cookies=cookies,
#    1869         auth=auth,
#    1870         follow_redirects=follow_redirects,
#    1871         timeout=timeout,
#    1872         extensions=extensions,
#    1873     )
#
# File ~/define/.venv/lib/python3.12/site-packages/httpx/_client.py:1540, in AsyncClient.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#    1525     warnings.warn(message, DeprecationWarning, stacklevel=2)
#    1527 request = self.build_request(
#    1528     method=method,
#    1529     url=url,
#    (...)   1538     extensions=extensions,
#    1539 )
# -> 1540 return await self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File ~/define/.venv/lib/python3.12/site-packages/httpx/_client.py:1629, in AsyncClient.send(self, request, stream, auth, follow_redirects)
#    1625 self._set_timeout(request)
#    1627 auth = self._build_request_auth(request, auth)
# -> 1629 response = await self._send_handling_auth(
#    1630     request,
#    1631     auth=auth,
#    1632     follow_redirects=follow_redirects,
#    1633     history=[],
#    1634 )
#    1635 try:
#    1636     if not stream:
#
# File ~/define/.venv/lib/python3.12/site-packages/httpx/_client.py:1657, in AsyncClient._send_handling_auth(self, request, auth, follow_redirects, history)
#    1654 request = await auth_flow.__anext__()
#    1656 while True:
# -> 1657     response = await self._send_handling_redirects(
#    1658         request,
#    1659         follow_redirects=follow_redirects,
#    1660         history=history,
#    1661     )
#    1662     try:
#    1663         try:
#
# File ~/define/.venv/lib/python3.12/site-packages/httpx/_client.py:1694, in AsyncClient._send_handling_redirects(self, request, follow_redirects, history)
#    1691 for hook in self._event_hooks["request"]:
#    1692     await hook(request)
# -> 1694 response = await self._send_single_request(request)
#    1695 try:
#    1696     for hook in self._event_hooks["response"]:
#
# File ~/define/.venv/lib/python3.12/site-packages/httpx/_client.py:1730, in AsyncClient._send_single_request(self, request)
#    1725     raise RuntimeError(
#    1726         "Attempted to send an sync request with an AsyncClient instance."
#    1727     )
#    1729 with request_context(request=request):
# -> 1730     response = await transport.handle_async_request(request)
#    1732 assert isinstance(response.stream, AsyncByteStream)
#    1733 response.request = request
#
# File ~/define/.venv/lib/python3.12/site-packages/httpx/_transports/default.py:394, in AsyncHTTPTransport.handle_async_request(self, request)
#     381 req = httpcore.Request(
#     382     method=request.method,
#     383     url=httpcore.URL(
#    (...)    391     extensions=request.extensions,
#     392 )
#     393 with map_httpcore_exceptions():
# --> 394     resp = await self._pool.handle_async_request(req)
#     396 assert isinstance(resp.stream, typing.AsyncIterable)
#     398 return Response(
#     399     status_code=resp.status,
#     400     headers=resp.headers,
#     401     stream=AsyncResponseStream(resp.stream),
#     402     extensions=resp.extensions,
#     403 )
#
# File ~/define/.venv/lib/python3.12/site-packages/httpcore/_async/connection_pool.py:256, in AsyncConnectionPool.handle_async_request(self, request)
#     253         closing = self._assign_requests_to_connections()
#     255     await self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#     260 assert isinstance(response.stream, typing.AsyncIterable)
#
# File ~/define/.venv/lib/python3.12/site-packages/httpcore/_async/connection_pool.py:236, in AsyncConnectionPool.handle_async_request(self, request)
#     232 connection = await pool_request.wait_for_connection(timeout=timeout)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = await connection.handle_async_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#     244     pool_request.clear_connection()
#
# File ~/define/.venv/lib/python3.12/site-packages/httpcore/_async/connection.py:103, in AsyncHTTPConnection.handle_async_request(self, request)
#     100     self._connect_failed = True
#     101     raise exc
# --> 103 return await self._connection.handle_async_request(request)
#
# File ~/define/.venv/lib/python3.12/site-packages/httpcore/_async/http2.py:96, in AsyncHTTP2Connection.handle_async_request(self, request)
#      86 if not self.can_handle_request(request.url.origin):
#      87     # This cannot occur in normal operation, since the connection pool
#      88     # will only send requests on connections that handle them.
#      89     # It's in place simply for resilience as a guard against incorrect
#      90     # usage, for anyone working directly with httpcore connections.
#      91     raise RuntimeError(
#      92         f"Attempted to send request to {request.url.origin} on connection "
#      93         f"to {self._origin}"
#      94     )
# ---> 96 async with self._state_lock:
#      97     if self._state in (HTTPConnectionState.ACTIVE, HTTPConnectionState.IDLE):
#      98         self._request_count += 1
#
# File ~/define/.venv/lib/python3.12/site-packages/httpcore/_synchronization.py:77, in AsyncLock.__aenter__(self)
#      75     await self._trio_lock.acquire()
#      76 elif self._backend == "asyncio":
# ---> 77     await self._anyio_lock.acquire()
#      79 return self
#
# File ~/define/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:1799, in Lock.acquire(self)
#    1797 if not self._fast_acquire:
#    1798     try:
# -> 1799         await AsyncIOBackend.cancel_shielded_checkpoint()
#    1800     except CancelledError:
#    1801         self.release()
#
# File ~/define/.venv/lib/python3.12/site-packages/anyio/_backends/_asyncio.py:2356, in AsyncIOBackend.cancel_shielded_checkpoint(cls)
#    2353 @classmethod
#    2354 async def cancel_shielded_checkpoint(cls) -> None:
#    2355     with CancelScope(shield=True):
# -> 2356         await sleep(0)
#
# File ~/.rye/py/cpython@3.12.5/lib/python3.12/asyncio/tasks.py:656, in sleep(delay, result)
#     654 """Coroutine that completes after a given time (in seconds)."""
#     655 if delay <= 0:
# --> 656     await __sleep0()
#     657     return result
#     659 loop = events.get_running_loop()
#
# File ~/.rye/py/cpython@3.12.5/lib/python3.12/asyncio/tasks.py:650, in __sleep0()
#     641 @types.coroutine
#     642 def __sleep0():
#     643     """Skip one event loop run cycle.
#     644
#     645     This is a private helper for 'asyncio.sleep()', used
#    (...)    648     instead of creating a Future object.
#     649     """
# --> 650     yield
#
# CancelledError:

# %%
import pyarrow.parquet as pq
import pyarrow.dataset as ds
path = "test2/0x478946bcd4a5a22b316470f5486fafb928c0ba25__topics-7ff435afcc/shards/shard_00002.parquet"
events = pq.read_table(path)
dataset = ds.dataset(path, format="parquet")
tbl = dataset.to_table()
df = tbl.to_pandas()

# %%
df[df["event"] == "Collect"]
# Out:
#         block_number  block_timestamp  \
# 1          124355675       1724310127
# 4          124355712       1724310201
# 7          124355838       1724310453
# 10         124355865       1724310507
# 13         124356063       1724310903
# ...              ...              ...
# 249987     126915282       1729429341
# 249989     126915287       1729429351
# 249991     126915288       1729429353
# 249996     126915306       1729429389
# 249998     126915307       1729429391
#
#                                                   tx_hash  log_index  \
# 1       0x1ad4e0a9b5070ac02fbd6c9780ef43227dbd3b50505d...         29
# 4       0xeb48b6278d1d52cffc82388067d7479f54c24ef97c4f...         29
# 7       0xc3ee1bbbe69d3ab9838edbd518377f86b3c3f8e71114...         18
# 10      0xe270a022a0fa71e38768a51e28edc746933f720af5cb...         23
# 13      0x316c1db0f13c9a05df3fe1d8acc7d8d53665387ecae8...         28
# ...                                                   ...        ...
# 249987  0x2e6849779003820408997a1ff7ffe3ab679670495877...         41
# 249989  0xa0cd16e25de6ba57ca50f19e1a648437ff6b2a03f902...         20
# 249991  0x8c2c245ccb172d467569e22af25f1fc1e2ee7ad58261...         43
# 249996  0xc674c6a572a6995884220f45747ad88d3236dff88510...         17
# 249998  0xfcac31e912ac0395c676e63689a12efc5fcf3eb12c4b...         14
#
#                                               pool    event  \
# 1       0x478946BcD4a5a22b316470F5486fAfb928C0bA25  Collect
# 4       0x478946BcD4a5a22b316470F5486fAfb928C0bA25  Collect
# 7       0x478946BcD4a5a22b316470F5486fAfb928C0bA25  Collect
# 10      0x478946BcD4a5a22b316470F5486fAfb928C0bA25  Collect
# 13      0x478946BcD4a5a22b316470F5486fAfb928C0bA25  Collect
# ...                                            ...      ...
# 249987  0x478946BcD4a5a22b316470F5486fAfb928C0bA25  Collect
# 249989  0x478946BcD4a5a22b316470F5486fAfb928C0bA25  Collect
# 249991  0x478946BcD4a5a22b316470F5486fAfb928C0bA25  Collect
# 249996  0x478946BcD4a5a22b316470F5486fAfb928C0bA25  Collect
# 249998  0x478946BcD4a5a22b316470F5486fAfb928C0bA25  Collect
#
#                                              owner sender  \
# 1       0x416b433906b1B72FA758e166e239c43d68dC6F29   None
# 4       0x416b433906b1B72FA758e166e239c43d68dC6F29   None
# 7       0x416b433906b1B72FA758e166e239c43d68dC6F29   None
# 10      0x416b433906b1B72FA758e166e239c43d68dC6F29   None
# 13      0x416b433906b1B72FA758e166e239c43d68dC6F29   None
# ...                                            ...    ...
# 249987  0x416b433906b1B72FA758e166e239c43d68dC6F29   None
# 249989  0x416b433906b1B72FA758e166e239c43d68dC6F29   None
# 249991  0x416b433906b1B72FA758e166e239c43d68dC6F29   None
# 249996  0x416b433906b1B72FA758e166e239c43d68dC6F29   None
# 249998  0x416b433906b1B72FA758e166e239c43d68dC6F29   None
#
#                                          recipient  tick_lower  tick_upper  \
# 1       0x3cDbbC3eCa52a65998B021C67982Bc72B2deCef0      197500      197600
# 4       0x3cDbbC3eCa52a65998B021C67982Bc72B2deCef0      197500      197600
# 7       0x3cDbbC3eCa52a65998B021C67982Bc72B2deCef0      197500      197600
# 10      0x3cDbbC3eCa52a65998B021C67982Bc72B2deCef0      197500      197600
# 13      0x3cDbbC3eCa52a65998B021C67982Bc72B2deCef0      197500      197600
# ...                                            ...         ...         ...
# 249987  0xed4B16e8c43AD2f6e08e6E9Bf1b8848644A8C6F6      197500      197600
# 249989  0x416b433906b1B72FA758e166e239c43d68dC6F29      197500      197600
# 249991  0xed4B16e8c43AD2f6e08e6E9Bf1b8848644A8C6F6      197500      197600
# 249996  0x3cDbbC3eCa52a65998B021C67982Bc72B2deCef0      197500      197600
# 249998  0x344353872521C6EFB2137F96edF487b4237BaB65      197500      197600
#
#        liquidity       amount0               amount1
# 1           None   13361719653  18987986361839144920
# 4           None   18523712846  18570718784596943627
# 7           None   26775023032  19123795067542388956
# 10          None   22918226515  19677682352691942230
# 13          None   18977867955  21175808453670394423
# ...          ...           ...                   ...
# 249987      None          1574                     0
# 249989      None   64042351647   2039342746927935968
# 249991      None   24110936587    767780420098263248
# 249996      None   80252837053   2555543901137420309
# 249998      None  258764195352   8239998553835321888
#
# [89824 rows x 14 columns]
